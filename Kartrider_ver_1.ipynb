# %%
import warnings
import requests
import pandas as pd
import json

warnings.filterwarnings(action='ignore')

def make_data(x):
    
    global df_total
    
    access_id = x
    start_date = '2021-06-01 00:00:00'
    end_date = '2022-01-01 00:00:00'
    offset = 0
    limit = 200
    match_types = ''

    api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2NvdW50X2lkIjoiMTA5MTM3MTU4NCIsImF1dGhfaWQiOiIyIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIiwic2VydmljZV9pZCI6IjQzMDAxMTM5MyIsIlgtQXBwLVJhdGUtTGltaXQiOiI1MDA6MTAiLCJuYmYiOjE2NDY4OTc1NTEsImV4cCI6MTY2MjQ0OTU1MSwiaWF0IjoxNjQ2ODk3NTUxfQ.W71VlNCXm948IEuTkxjqXMwPeVk0cAbsKhPppb1YbAI'
    headers = {'Authorization': api}
    _API_URL = f'https://api.nexon.co.kr/kart/v1.0/users/{access_id}/matches?start_date={start_date}&end_date={end_date} &offset={offset}&limit={limit}&match_types={match_types}'
    res = requests.get(_API_URL, headers = headers)
    data=res.json()

    match_data = data['matches'][0]['matches']
    df_match=pd.DataFrame(match_data)
    player_key = df_match['player'][0].keys()
    player_key_list = list(player_key)
    df_player=pd.DataFrame()

    for i in range(len(df_match)):
        df_player[i] = df_match['player'][i].values()

    df_player= df_player.T
    df_player.columns = player_key_list
    df_player.drop(['accountNo','characterName','character'],axis=1,inplace=True)
    df_result = pd.concat([df_match,df_player],axis=1)
    df_result.drop(['player'],axis=1,inplace=True)
    df_total = pd.concat([df_total,df_result],axis=0)
    
    return df_total

access_id = '1242159681'
start_date = '2021-06-01 00:00:00'
end_date = '2022-01-01 00:00:00'
offset = 0
limit = 200
match_types = ''

api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2NvdW50X2lkIjoiMTA5MTM3MTU4NCIsImF1dGhfaWQiOiIyIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIiwic2VydmljZV9pZCI6IjQzMDAxMTM5MyIsIlgtQXBwLVJhdGUtTGltaXQiOiI1MDA6MTAiLCJuYmYiOjE2NDY4OTc1NTEsImV4cCI6MTY2MjQ0OTU1MSwiaWF0IjoxNjQ2ODk3NTUxfQ.W71VlNCXm948IEuTkxjqXMwPeVk0cAbsKhPppb1YbAI'
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/users/{access_id}/matches?start_date={start_date}&end_date={end_date} &offset={offset}&limit={limit}&match_types={match_types}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

match_data = data['matches'][0]['matches']
df_match=pd.DataFrame(match_data)
player_key = df_match['player'][0].keys()
player_key_list = list(player_key)
df_player=pd.DataFrame()

for i in range(len(df_match)):
    df_player[i] = df_match['player'][i].values()

df_player= df_player.T
df_player.columns = player_key_list
df_player.drop(['accountNo','characterName','character'],axis=1,inplace=True)
df_result = pd.concat([df_match,df_player],axis=1)
df_result.drop(['player'],axis=1,inplace=True)
df_total = df_result

member_list = ['167800927','2097689234','638197971','587611739','117614495','856291007','957139120','1024112561','1577415962',
               '1593946477','1862768295','1493536274','1409531473','353187063','268643831','1846067531','1325969169','1007340789',
               '101335392','738400586','1711522509','604167264','620786362','1258489521','1644311523','134525754','537007972',
               '1057472778','1510585642','1175053980','1174627112','553648658','570861461','2130932073','218639036','1493376471',
               '503468732','704783392','134417347','33803562','537117766','1024022825','336071572','1963320149','503355757',
               '1963163935','1258754161','84232389','1644385002','1258686264','1661308522','470409472','1359522522','402746435',
               '739037596','1963778978','302589443','1107659585','704910077','537382874','50921777','739006278','788776421',
               '1846071695','805828347','788603947','1073860980','721685417','470066031','939647716','1929684884','1409316184',
               '561568','1191414771','1091172790','235577525','84146908',"1895982260","33703124","470461754","923416175",
               "1275278123","437035834","1275342943","1593982949","1493506094","402953956","1325725048","1627993704","251944965",
               "906181257","168434138","1057218182","1006956762","1158312784","1326053448","1024068817","487170313","1443478445"]

for i in member_list:
    make_data(i)

df_total.to_csv('Kartrider_total.csv',encoding='utf-8-sig')
